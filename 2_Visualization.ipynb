# %% [markdown]
# ##Visualization

# %% [markdown]
# [Classification Data: ](https://www.kaggle.com/loveall/cervical-cancer-risk-classification)
#
# [Regression Data](https://www.kaggle.com/sansuthi/life-expectancy)

# %% [markdown]
# Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Data 

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Data Science/lifeExpectancy_world.csv')

df
# Out:
#              Entity      Code    1950    1951  ...    2016    2017    2018    2019
# 0       Afghanistan       AFG  27.638  27.878  ...  63.763  64.130  64.486  64.833
# 1            Africa       NaN  36.450  36.712  ...  62.064  62.472  62.839  63.170
# 2           Albania       ALB  54.191  54.399  ...  78.194  78.333  78.458  78.573
# 3           Algeria       DZA  42.087  42.282  ...  76.298  76.499  76.693  76.880
# 4    American Samoa       ASM  63.775  63.901  ...  73.609  73.636  73.679  73.745
# ..              ...       ...     ...     ...  ...     ...     ...     ...     ...
# 238  Western Sahara       ESH  34.753  34.946  ...  69.496  69.762  70.017  70.263
# 239           World  OWID_WRL  45.733  46.069  ...  71.928  72.169  72.386  72.584
# 240           Yemen       YEM  29.097  29.132  ...  66.087  66.086  66.096  66.125
# 241          Zambia       ZMB  42.306  42.537  ...  62.464  63.043  63.510  63.886
# ...

# %%
# 2D Plots
data = df.iloc[239]
data
# Out:
# Entity       World
# Code      OWID_WRL
# 1950        45.733
# 1951        46.069
# 1952        46.712
#             ...
# 2015        71.661
# 2016        71.928
# 2017        72.169
# 2018        72.386
# 2019        72.584
# Name: 239, Length: 72, dtype: object

# %%
x = data.index[20:30]
x
# Out:
# Index(['1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977'],
#       dtype='object')

# %%
y = data[20:30]
y
# Out:
# 1968    55.636
# 1969    56.314
# 1970    56.911
# 1971    57.436
# 1972    57.916
# 1973    58.374
# 1974    58.818
# 1975    59.251
# 1976    59.674
# 1977    60.083
# Name: 239, dtype: object

# %%
# 2D scatter plots

plt.plot(x, y, 'b')
plt.xlabel('Year')
plt.ylabel('Average Lifespan')
plt.title('Lifespan of The World')
plt.show()

# %% [markdown]
# Seaborn

# %%
import seaborn as sns

# %%
df2 = pd.DataFrame({'Year':data.index[2:], 'Lifespan':data[2:][0]})

df2.head()
# Out:
#       Year Lifespan
# 1950  1950   45.733
# 1951  1951   46.069
# 1952  1952   46.712
# 1953  1953   47.295
# 1954  1954    47.82

# %%
data2 = df2[10:50]
data2
# Out:
#       Year Lifespan
# 1960  1960   50.137
# 1961  1961   50.573
# 1962  1962   51.098
# 1963  1963   51.726
# 1964  1964   52.451
# 1965  1965   53.248
# 1966  1966   54.075
# 1967  1967   54.884
# 1968  1968   55.636
# 1969  1969   56.314
# 1970  1970   56.911
# 1971  1971   57.436
# 1972  1972   57.916
# 1973  1973   58.374
# 1974  1974   58.818
# 1975  1975   59.251
# 1976  1976   59.674
# 1977  1977   60.083
# 1978  1978   60.475
# 1979  1979   60.852
# 1980  1980   61.219
# 1981  1981    61.58
# 1982  1982   61.937
# 1983  1983   62.289
# 1984  1984   62.635
# 1985  1985   62.965
# 1986  1986    63.27
# 1987  1987   63.545
# 1988  1988   63.785
# 1989  1989   63.995
# 1990  1990    64.18
# 1991  1991   64.347
# 1992  1992   64.509
# 1993  1993   64.676
# 1994  1994   64.857
# 1995  1995   65.054
# 1996  1996   65.269
# 1997  1997   65.499
# 1998  1998   65.743
# 1999  1999   66.001

# %% [markdown]
# Seaborn
#
# [example](https://seaborn.pydata.org/introduction.html)

# %%
## Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
